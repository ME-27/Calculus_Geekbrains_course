# %% [markdown]
# # Домашнее задание № 8

# %% [markdown]
# ## по дисциплине: Введение в математический анализ

# %% [markdown]
# ## Тема: Производная функции нескольких переменных. Часть 2

# %% [markdown]
# ### выполнил: Евгений Кириллов

# %% [markdown]
# __1.__ Исследовать на условный экстремум функцию
#
# ### $$U=3-8x+6y,$$
#
# если
#
# ### $$x^2+y^2=36$$

# %% [markdown]
# составим функцию Лагранжа:

# %% [markdown]
# ### $$L(x,y,\lambda)=3-8x+6y +\lambda \cdot (x^2+y^2-36)$$

# %% [markdown]
# найдем частные производные, приравняем их к нулю и решим систему уравнений:

# %% [markdown]
# ### $$\begin{cases}L'_{x}=-8+2\lambda x=0 \\L'_{y}=6+2\lambda y=0 \\L'_{\lambda}=x^2+y^2-36=0\end{cases}$$

# %% [markdown]
# ### $$\Rightarrow \begin{cases} x=\frac{4}{\lambda} \\ y=\frac{3}{\lambda} \\ \lambda^2=\frac{25}{36}\end{cases}$$

# %% [markdown]
# #### $$\Rightarrow \left[ \begin{gathered} \left\{\begin{gathered}x=\frac{24}{5} \\ y=\frac{18}{5} \\ y=\frac{5}{6}\end{gathered}\right. \\ \left\{\begin{gathered}x=-\frac{24}{5} \\ y=-\frac{18}{5} \\ y=-\frac{5}{6} \end{gathered}\right.\end{gathered} \right.$$

# %% [markdown]
# получаем две точки $(\frac{24}{5},\frac{18}{5},\frac{5}{6})$ и $(-\frac{24}{5},-\frac{18}{5},-\frac{5}{6})$

# %% [markdown]
# найдём вторые производные:

# %% [markdown]
# ### $$L''_{xx}=2\lambda \\
# L''_{xy}=0 \\
# L''_{x\lambda}=2x$$

# %% [markdown]
# ### $$L''_{yx}=0 \\
# L''_{yy}=2\lambda \\
# L''_{y\lambda}=2y$$

# %% [markdown]
# ### $$L''_{\lambda x}=2x \\
# L''_{\lambda y}=2y \\
# L''_{\lambda\lambda}=0$$

# %% [markdown]
# далее найдем определитель в общем виде, а затем уже разберемся с каждой точкой:

# %% [markdown]
# ### $$\Delta=\begin{vmatrix}
# 2\lambda & 0 & 2x\\
# 0 & 2\lambda & 2y\\
# 2x & 2y & 0\\
# \end{vmatrix}=
# \begin{vmatrix}
# + & - & +\\
# - & + & -\\
# + & - & +\\
# \end{vmatrix}=2\lambda \cdot
# \begin{vmatrix}
# 2\lambda & 2y\\
# 2y & 0\\
# \end{vmatrix}-0\cdot
# \begin{vmatrix}
# 0 & 2y\\
# 2x & 0\\
# \end{vmatrix}+2x\cdot
# \begin{vmatrix}
# 0 & 2\lambda\\
# 2x & 2y\\
# \end{vmatrix}\\=2\lambda \cdot (2\lambda \cdot0-2y\cdot2y)-0+2x\cdot(0\cdot2y - 2\lambda\cdot2x) = -8\lambda(x^2+y^2)$$

# %% [markdown]
# по условию $x^2+y^2=36$, тогда

# %% [markdown]
# ### $$\Delta=-8\lambda \cdot 36=-288\lambda$$

# %% [markdown]
# т.е. знак определителя засисит только от знака $\lambda$

# %% [markdown]
# #### если $\lambda=\frac{5}{6}$, то $\Delta<0$, следовательно $(\frac{24}{5},\frac{18}{5},\frac{5}{6})$ - точка минимума

# %% [markdown]
# #### если $\lambda=-\frac{5}{6}$, то $\Delta>0$, следовательно $(-\frac{24}{5},-\frac{18}{5},-\frac{5}{6})$ - точка максимума

# %% [markdown]
# __2.__ Исследовать на условный экстремум функцию
#
# ### $$U=2x^2+12xy+32y^2+15,$$
#
# если
#
# ### $$x^2+16y^2=64$$

# %% [markdown]
# составим функцию Лагранжа:

# %% [markdown]
# ### $$L(x,y,\lambda)=2x^2+12xy+32y^2+15+\lambda \cdot (x^2+16y^2-64)$$

# %% [markdown]
# найдем частные производные, приравняем их к нулю и решим систему уравнений:

# %% [markdown]
# ### $$\begin{cases}L'_{x}=4x+12y+2\lambda x=0, \\L'_{y}=12x+64y+32\lambda y=0, \\L'_{\lambda}=x^2+16y^2-64=0 \end{cases}$$

# %% [markdown]
# ### $$\Rightarrow\begin{cases} x=-\frac{12y}{4+2\lambda} \\ 12(-\frac{12y}{4+2\lambda})+64y+32\lambda y=0 \\ x^2+16y^2-64=0\end{cases}$$

# %% [markdown]
# ### $$\Rightarrow\begin{cases} x=-\frac{12y}{4+2\lambda} \\
# \left[
# \begin{gathered}
# \lambda = -\frac{7}{2} \\
# \lambda = -\frac{1}{2}
# \end{gathered}
# \right.\\
# x^2+16y^2-64=0\end{cases}$$

# %% [markdown]
# ### $$\Rightarrow
# \left[
#     \begin{gathered}
#         \left\{
#         \begin{gathered}
#             \lambda =-\frac{7}{2} \\
#             x=4y \\
#             \left[
#             \begin{gathered}
#                 y=\sqrt{2} \\
#                 y=-\sqrt{2}
#             \end{gathered}
#             \right.
#         \end{gathered}
#         \right. \\
#         \left\{
#         \begin{gathered}
#             \lambda =-\frac{1}{2} \\
#             x=-4y \\
#             \left[
#             \begin{gathered}
#                 y=\sqrt{2} \\
#                 y=-\sqrt{2}
#             \end{gathered}
#             \right.
#         \end{gathered}
#         \right.
#     \end{gathered}
# \right.$$

# %% [markdown]
# получаем четыре точки
# $(4\sqrt{2},\sqrt{2},-\frac{7}{2})$,
# $(-4\sqrt{2},-\sqrt{2},-\frac{7}{2})$,
# $(-4\sqrt{2},\sqrt{2},-\frac{1}{2})$,
# $(4\sqrt{2},-\sqrt{2},-\frac{1}{2})$

# %% [markdown]
# найдём вторые производные:

# %% [markdown]
# ### $$L''_{xx}=4+2\lambda \\
# L''_{xy}=12 \\
# L''_{x\lambda}=2x$$

# %% [markdown]
# ### $$L''_{yx}=12 \\
# L''_{yy}=64+32\lambda \\
# L''_{y\lambda}=32y$$

# %% [markdown]
# ### $$L''_{\lambda x}=2x \\
# L''_{\lambda y}=32y \\
# L''_{\lambda\lambda}=0$$

# %% [markdown]
# далее найдем определитель в общем виде, а затем уже разберемся с каждой точкой:

# %% [markdown]
# ### $$\Delta=\begin{vmatrix}
# 4+2\lambda & 12 & 2x\\
# 12 & 64+32\lambda & 32y\\
# 2x & 32y & 0\\
# \end{vmatrix}=-256(x^2+16y^2)-126\lambda(x^2+16y^2)+1536xy$$

# %% [markdown]
# по условию $x^2+16y^2=64$, тогда

# %% [markdown]
# ### $$\Delta=-256\cdot64-126\lambda\cdot64+1536xy=-16384-8192\lambda+1536xy$$

# %% [markdown]
# точкa $(4\sqrt{2},\sqrt{2},-\frac{7}{2})$:

# %% [markdown]
# ### $$\Delta=-16384-8192\cdot(-\frac{7}{2})+1536\cdot4\sqrt{2}\cdot \sqrt{2}>0$$

# %% [markdown]
# #### следовательно, точкa $(4\sqrt{2},\sqrt{2},-\frac{7}{2})$ - точка максимума

# %% [markdown]
# точкa $(-4\sqrt{2},-\sqrt{2},-\frac{7}{2})$:

# %% [markdown]
# ### $$\Delta=-16384-8192\cdot(-\frac{7}{2})+1536\cdot(-4\sqrt{2})\cdot (-\sqrt{2})>0$$

# %% [markdown]
# #### следовательно, точкa $(-4\sqrt{2},-\sqrt{2},-\frac{7}{2})$ - точка максимума

# %% [markdown]
# точкa $(-4\sqrt{2},\sqrt{2},-\frac{1}{2})$:

# %% [markdown]
# ### $$\Delta=-16384-8192\cdot(-\frac{1}{2})+1536\cdot(-4\sqrt{2})\cdot \sqrt{2}<0$$

# %% [markdown]
# #### следовательно, точкa $(-4\sqrt{2},\sqrt{2},-\frac{1}{2})$ - точка минимума

# %% [markdown]
# точкa $(4\sqrt{2},-\sqrt{2},-\frac{1}{2})$:

# %% [markdown]
# ### $$\Delta=-16384-8192\cdot(-\frac{1}{2})+1536\cdot4\sqrt{2}\cdot(-\sqrt{2})<0$$

# %% [markdown]
# #### следовательно, точкa $(4\sqrt{2},-\sqrt{2},-\frac{1}{2})$ - точка минимума

# %% [markdown]
# __3.__ Численно найти хотя бы один действительный корень системы нелинейных уравнений:
# ### $$\begin{cases}
#    x^2-y^2+3xy^3-2x^2y^2+2x-3y-5=0 \\
#    3y^3-2x^2+2x^3y-5x^2y^2+5=0
#  \end{cases}$$

# %%
from scipy.optimize import fsolve, broyden1
import math

def equations(p):
    x, y = p
    # Запись системы уравнения вида x+y=2, x-y=0
    return (x**2 - y**2 + 3*x*y**3 - 2*x**2*y**2 + 2*x - 3*y - 5, 3*y**3 - 2*x**2 + 2*x**3*y - 5*x**2*y**2 + 5)

# Численное решение системы уравнений
(x, y), info, ier, mesg =  fsolve(equations, (10, 10), full_output=True)
print(x, y, ier)
# Out:
# 1.273302064528599 1.6620391224277693 1

# %% [markdown]
# __4*.__ Численно найти все $5$ действительных корней.

# %%
import numpy as np
from scipy.optimize import fsolve, broyden2
import math

def equations(p):
    x, y = p
    return (x**2 - y**2 + 3*x*y**3 - 2*x**2*y**2 + 2*x - 3*y - 5, 3*y**3 - 2*x**2 + 2*x**3*y - 5*x**2*y**2 + 5)

solv = set()
for x in np.arange(-100, 100, 1):
    for y in np.arange(-100, 100, 1):
        (x, y), info, ier, mesg =  fsolve(equations, (x, y), full_output=True)
        if (ier == 1): solv.add((int(x*10**8)/10**8, int(y*10**8)/10**8))
            
print(solv)
# Out:
# {(1.37568714, -0.17475798), (1.27330206, 1.66203912), (2.49435653, 0.70831752), (-3.65307996, -0.27476341), (2.21775363, 0.61019398), (2.21775363, 0.61019397)}
