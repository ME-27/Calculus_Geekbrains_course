# %% [markdown]
# # Домашнее задание № 7

# %% [markdown]
# ## по дисциплине: Введение в математический анализ

# %% [markdown]
# ## Тема: Производная функции нескольких переменных. Часть 1

# %% [markdown]
# ### выполнил: Евгений Кириллов

# %% [markdown]
# __1.__ Найти частные производные первого и второго порядка. Убедиться в равенстве смешанных производных.
#
# ### $$U=x^3+3xy^2+z^2-39x-36y+2z+26$$

# %% [markdown]
# Найдем все частные производные первого и второго порядка.

# %% [markdown]
# ### $$U'_{x}=3x^2+3y^2-39$$

# %% [markdown]
# ### $$U'_{y}=6xy-36$$

# %% [markdown]
# ### $$U'_{z}=2z+2$$

# %% [markdown]
# ### $$U''_{xx}=6x$$

# %% [markdown]
# ### $$U''_{xy}=6y$$

# %% [markdown]
# ### $$U''_{xz}=0$$

# %% [markdown]
# ### $$U''_{yx}=6y$$

# %% [markdown]
# ### $$U''_{yy}=6x$$

# %% [markdown]
# ### $$U''_{yz}=0$$

# %% [markdown]
# ### $$U''_{zx}=0$$

# %% [markdown]
# ### $$U''_{zy}=0$$

# %% [markdown]
# ### $$U''_{zz}=2$$

# %% [markdown]
# Убедимся в равенстве смешанных производных.

# %% [markdown]
# ### $$U''_{xy}=U''_{yx}$$

# %% [markdown]
# ### $$U''_{xz}=U''_{zx}$$

# %% [markdown]
# ### $$U''_{yz}=U''_{zy}$$

# %% [markdown]
# __2.__ Найти частные производные первого и второго порядка. Убедиться в равенстве смешанных производных.
#
# ### $$U=\frac{256}{x}+\frac{x^2}{y}+\frac{y^2}{z}+z^2$$

# %% [markdown]
# ### $$U=\frac{256}{x}+\frac{x^2}{y}+\frac{y^2}{z}+z^2=256x^{-1}+x^2y^{-1}+y^2z^{-1}+z^2$$

# %% [markdown]
# ### $$U'_{x}=-256x^{-2}+2xy^{-1}$$

# %% [markdown]
# ### $$U'_{y}=-x^2y^{-2}+2yz^{-1}$$

# %% [markdown]
# ### $$U'_{z}=-y^2z^{-2}+2z$$

# %% [markdown]
# ### $$U''_{xx}=512x^{-3}+2y^{-1}$$

# %% [markdown]
# ### $$U''_{xy}=-2xy^{-2}$$

# %% [markdown]
# ### $$U''_{xz}=0$$

# %% [markdown]
# ### $$U''_{yx}=-2xy^{-2}$$

# %% [markdown]
# ### $$U''_{yy}=2x^2y^{-3}+2z^{-1}$$

# %% [markdown]
# ### $$U''_{yz}=-2yz^{-2}$$

# %% [markdown]
# ### $$U''_{zx}=0$$

# %% [markdown]
# ### $$U''_{zy}=-2yz^{-2}$$

# %% [markdown]
# ### $$U''_{zz}=2y^2z^{-3}+2$$

# %% [markdown]
# Убедимся в равенстве смешанных производных.

# %% [markdown]
# ### $$U''_{xy}=U''_{yx}$$

# %% [markdown]
# ### $$U''_{xz}=U''_{zx}$$

# %% [markdown]
# ### $$U''_{yz}=U''_{zy}$$

# %% [markdown]
# __3.__ Найти производную функции $U=x^2+y^2+z^2$ по направлению вектора $\overrightarrow{c}(-9,8,-12)$ в точке $M(8,-12,9)$

# %% [markdown]
# Найдем длину вектора $\overrightarrow{c}$:

# %% [markdown]
# ### $$|\overrightarrow{c}|=\sqrt{x^2_{0}+y^2_{0}+z^2_{0}}=\sqrt{(-9)^2+8^2+(-12)^2}=\sqrt{289}=17$$

# %% [markdown]
# Запишем единичный вектор $\overrightarrow{c}_{0}$:

# %% [markdown]
# ### $$\overrightarrow{c_{0}}=\frac{\overrightarrow{c}}{|\overrightarrow{c}|}=\Bigr(-\frac{9}{17},\frac{8}{17},-\frac{12}{17}\Bigl)$$

# %% [markdown]
# Теперь найдем градиент в точке 𝑀(8,−12,9).

# %% [markdown]
# ### $$U'_{x}=2x$$

# %% [markdown]
# ### $$U'_{y}=2y$$

# %% [markdown]
# ### $$U'_{z}=2z$$

# %% [markdown]
# ### $$\mbox{grad}U=(2\cdot8,2\cdot(-12),11\cdot9)=(16,-24,18)$$

# %% [markdown]
# Посчитаем значение производной.

# %% [markdown]
# ### $$U'_{\overrightarrow{c}}=-\frac{9}{17}\cdot16+\frac{8}{17}\cdot(-24)-\frac{12}{17}\cdot18=-\frac{552}{17}$$

# %% [markdown]
# __4.__ Найти производную функции $U=e^{x^2+y^2+z^2}$ по направлению вектора $\overrightarrow{c}(4,-13,-16)$ в точке $L(-16,4,-13)$

# %% [markdown]
# Найдем длину вектора $\overrightarrow{c}$:

# %% [markdown]
# ### $$|\overrightarrow{c}|=\sqrt{x^2_{0}+y^2_{0}+z^2_{0}}=\sqrt{4^2+(-13)^2+(-16)^2}=21$$

# %% [markdown]
# Запишем единичный вектор $\overrightarrow{c}_{0}$:

# %% [markdown]
# ### $$\overrightarrow{c_{0}}=\frac{\overrightarrow{c}}{|\overrightarrow{c}|}=\Bigr(\frac{4}{21},-\frac{13}{21},-\frac{16}{21}\Bigl)$$

# %% [markdown]
# Теперь найдем градиент в точке 𝐿(−16,4,−13).

# %% [markdown]
# ### $$U'_{x}=2xe^{x^2+y^2+z^2}$$

# %% [markdown]
# ### $$U'_{y}=2ye^{x^2+y^2+z^2}$$

# %% [markdown]
# ### $$U'_{z}=2ze^{x^2+y^2+z^2}$$

# %% [markdown]
# ### $$\mbox{grad}U=(-32e^{441},8e^{441},-26e^{441})$$

# %% [markdown]
# Посчитаем значение производной.

# %% [markdown]
# ### $$U'_{\overrightarrow{c}}=\frac{4}{21}\cdot(-32)\cdot e^{441}-\frac{13}{21}\cdot8\cdot e^{441}-\frac{16}{21}\cdot(-26)\cdot e^{441}=\frac{184}{21}e^{441}$$

# %% [markdown]
# __6.__ Исследовать на экстремум функцию:
#
# ### $$U=x^2y+\frac{1}{3}y^3+2x^2+3y^2-1$$

# %% [markdown]
# Найдем частные производные, приравняем их к нулю и найдем стационарные точки:

# %% [markdown]
# ### $$\begin{cases} U'_{x}=2xy+4x=0, \\ U'_{y}=x^2+y^2+6y=0\end{cases}$$

# %% [markdown]
# ### $$\begin{cases} x=0, \\ y=-2, \\ x^2+y^2+6y=0\end{cases}$$

# %% [markdown]
# ### $$\begin{cases} x=0, \\ y^2+6y=0, \\ y=-2, \\ x^2=8\end{cases}$$

# %% [markdown]
# Получаем точки (0,0), (0,-6), ($2\sqrt2$,-2), ($-2\sqrt2$,-2)

# %% [markdown]
# Теперь найдем вторые производные и составим матрицу Гёссе:

# %% [markdown]
# ###  $$U''_{xx}=2y+4$$

# %% [markdown]
# ###  $$U''_{xy}=U''_{yx}=2x$$

# %% [markdown]
# ###  $$U''_{yy}=2y+6$$

# %% [markdown]
# ###  $$\begin{pmatrix} 2y+4 & 2x\\ 2x & 2y+6\\ \end{pmatrix}$$

# %% [markdown]
# Теперь можно вычислить главные миноры:

# %% [markdown]
# ### $$\Delta_{1}=U''_{xx}=2y+4$$

# %% [markdown]
# ### $$\Delta_{2}=\begin{vmatrix} U''_{xx} & U''_{xy}\\ U''_{yx} & U''_{yy}\\ \end{vmatrix}=U''_{xx}\cdot U''_{yy}-(U''_{xy})^2=(2y+4)(2y+6)-(2x)^2=-4x^2+4y^2+20y+24$$

# %% [markdown]
# Проверим знаки миноров для точки (0,0).

# %% [markdown]
# ### $$\Delta_{1}=2y+4=2\cdot 0+4>0$$

# %% [markdown]
# ### $$\Delta_{2}=-4x^2+4y^2+20y+24=-4\cdot0^2+4\cdot 0^2+20\cdot 0+24>0$$

# %% [markdown]
# точка (0,0) является точкой минимума

# %% [markdown]
# Проверим знаки миноров для точки (0,-6).

# %% [markdown]
# ### $$\Delta_{1}=2y+4=2\cdot (-6)+4<0$$

# %% [markdown]
# ### $$\Delta_{2}=-4x^2+4y^2+20y+24=-4\cdot0^2+4\cdot (-6)^2+20\cdot (-6)+24>0$$

# %% [markdown]
# точка (0,-6) является точкой максимума

# %% [markdown]
# Проверим знаки миноров для точки ($2\sqrt2$,-2).

# %% [markdown]
# ### $$\Delta_{1}=2y+4=2\cdot (-2)+4=0$$

# %% [markdown]
# тупик
