# %%
Линейная регрессия в многомерном случае

# %% [markdown]
# ![32.PNG](attachment:32.PNG)

# %% [markdown]
# ![5.PNG](attachment:5.PNG)

# %% [markdown]
# ![6.PNG](attachment:6.PNG)

# %% [markdown]
# ![65.PNG](attachment:65.PNG)

# %%
Поиск коэффициентов лог регрессии в общем случае методом градиентного спуска

# %% [markdown]
# ![24.PNG](attachment:24.PNG)

# %% [markdown]
# ![25.PNG](attachment:25.PNG)

# %% [markdown]
# ![26.PNG](attachment:26.PNG)

# %%
Нейросети
