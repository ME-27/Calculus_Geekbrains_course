# %%
Что было в одномерном случае

# %% [markdown]
# ![%D0%91%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%20%284%29.png](attachment:%D0%91%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%20%284%29.png)

# %%
В случае функции f:R->R (число отображает в число) у нас не было вариантов, кроме как брать изменение только на одной оси
Мы брали точку x, небольшое приращение и определяли производную как следующий предел(=скорость роста=коэф касательной прямой)

# %%
Теперь мы будем рассматривать функции f:R^n->R (Виноградов рассматривает из R^n в R^m)

# %%
Например функция от двух переменных f(x,y)=x^2y отображает R^2 в R и т.д.

# %%
Мы уже рассматривали функцию от нескольких переменных в прошлом уроке когда говорили о функции площади поверхности цилиндра 
и т.д.
В общем случае площадь поверхности цилиндра состоит из 2 площадей кругов и площади боковой поверхности, то есть
S=2*pi*r^2 + 2pi*r*h
Как видно, это функция от 2 переменных

# %%
Здесь интуитивно возникает идея частных производных, а именно что можно смотреть как будет меняться функция, если только
одна из переменных меняется а другая нет. В таком случае надо дифференцировать по одной переменной считая другую за константу.
Частные производные будут:

S'_{r}=4*pi*r+2*pi*h
S'_{h}=2*pi*r

# %%
Это не сильно сложнее чем считать производную в одномерном случае только помним что одну из переменных мы считаем 
меняющейся, а другую нет. по сути мы разложили многомерную задачу на набор одномерных

# %%
Можно потренироваться считать такие производные для всяких абстрактных функций f(x,y,z)=x^2y+sin(1/xz+y) и т.д.

# %%
Градиентом называется вектор частных производных (f'(x),f'(y),f'(z)).

# %%
Он является вектором, показывающим скорость наибольшего роста функции f в точке (x,y,z). Он показывает крутизну спуска или 
подъема в данной точке. Геометрически он связан с касательной плоскостью

# %% [markdown]
# ![%D0%93%D1%80%D0%B0%D0%B4%D0%B8%D0%B5%D0%BD%D1%82_%D1%85%D0%BE%D0%BB%D0%BC%D0%B0.gif](attachment:%D0%93%D1%80%D0%B0%D0%B4%D0%B8%D0%B5%D0%BD%D1%82_%D1%85%D0%BE%D0%BB%D0%BC%D0%B0.gif)

# %% [markdown]
# ![12.PNG](attachment:12.PNG)

# %%
Здесь изображена картинка холма. Ее можно задать функцией от 2 переменных например f(x)=e^(-(x^2+y^2))
Тогда в произвольной точке её градиент это (-2x*e^(-(x^2+y^2)),-2y*e^(-(x^2+y^2)))

# %%
Например в точке (x,y)=(0.5,0.8) он будет равен около (-0.4,-0.6)

# %%
Можно увидеть что он будет направлен в сторону локального максимума

# %%
Например у функции x^2+y^2 будет минимум в 0 и вектор градиента будет (2x,2y) то есть в любой точке этот вектор будет 
направлен в сторону наибольшего возрастания

# %% [markdown]
# ![13.PNG](attachment:13.PNG)

# %%
В общем случае градиент это вектор который можно подсчитать в каждой точке и он задаст направление наибольшей крутизны
графика поверхности

# %% [markdown]
# ![14.PNG](attachment:14.PNG)

# %%
Для функции e^(-x^2+y^2) можем подсчитать градиент в отдельных точках

# %% [markdown]
# ![12.PNG](attachment:12.PNG)

# %% [markdown]
# ![15.PNG](attachment:15.PNG)

# %% [markdown]
# ![16.PNG](attachment:16.PNG)

# %% [markdown]
# ![17.PNG](attachment:17.PNG)

# %% [markdown]
# ![18.PNG](attachment:18.PNG)

# %%
Если рассматривать функцию из R^2 -> R^2 (x,y) -> (u(x,y),v(x,y)) то возникает не градиент (вектор)
а матрица с частными производными

# %%
Есть всякие преобразования плоскости например из декартовых в полярные координаты в которых будет возникать такая
матрица из частных производных. Она называется матрицей Якоби

# %% [markdown]
# Поиски экстремумов функций нескольких переменных

# %% [markdown]
# ![19.PNG](attachment:19.PNG)

# %%
Если мы хотим найти максимум многомерной функции то можно посчитать частные производные и приравнять к 0 и это
будет что-то типа необходимого условия для экстремума но не достаточного
Еще одним вариантом является путешествовать по градиенту, то есть берем произвольную точку, откладываем градиент в этой
точке (подобно компасу он покажет где направление макс) и берем точку на конце вектора градиента и повторяем операцию
Это подобно тому как мы делали в методе Ньютона для одномерного случая.
Чтобы найти минимум мы тогда должны двигаться в сторону соответствующую минус градиенту
Если мы будем двигаться в сторону перпендикулярную градиенту,то всегда будем ходить по кругу
Достаточные условия для экстремума описаны в методичке

# %% [markdown]
# В одномерном случае мы говорили о производной  функции. Здесь аналогом производной будет линейный оператор такой что
# $$f(x,y)=f(a,b)+ (f'_{x}(a,b),f'_{y}(a,b))(x-a,y-b)+o(x-a,y-b) , (x,y)->(a,b)$$

# %%
Это приводит к понятию производной по направлению то есть  мы понимаем что если

# %%
Пусть x=a+t,y=b

# %%
f(x,y)=f(a,b)+f'_{x}(a,b)t +o(t)

# %%
f'{x}(a,b)=lim(t->0)(f(a+t,b)-f(a,b)/t)

# %%
так мы придем к частной производной

# %%
В общем случае можно находить производную по любому направлению то есть нужно рассмотреть сужение f на
на прямую проходящую через точку (a,b) заданную любым направляющим вектором. Тогда в ней можно найти производную 
по направлению которая будет получаться как скалярное произведение вектора градиента на ваш вектор направления
То есть это позволяет понимать как

# %% [markdown]
# ![4%D1%83%D1%86.PNG](attachment:4%D1%83%D1%86.PNG)

# %%
Одним словом, если в одномерном случае мы приближали функцию линейной функцией то здесь многомерная функция приближается
многомерной линейной функцией или линейным оператором. Чтобы найти производную функции f(x,y) в точке (a,b) по направлению
h нужно найти частные производные f'_{x},f'_{y} в точке (x,y)=(a,b) тем самым получив вектор градиента
и взяв скалярное произведение с направлением h получить число считающееся значением производной. То есть это то как будет
меняться значение функции если точка стремится к точке (a,b) определенным образом. Еще это является по сути направлением к 
экстремуму при том моменте что мы решили пойти по направлению h то есть что-то типа отклоненного градиента

# %% [markdown]
# ![433.PNG](attachment:433.PNG)

# %%
dz- полный дифференциал f(x,y) (линейный оператор результатом выполнения которого является скалярное произведение
                               градиента на ваш вектор приращения который вы можете выбрать как хотите)
